# %% [markdown]
# # Practice #1
# * Task: Binary classification using Logistic Regression (cross-entropy loss)
# * Input: 2-dim vector, x = {x1,x2}
# * Output: label of the input, y = 0 or 1

# %%
# Generate 1000 train set, 100 test set
import random
import numpy as np
import time

def x_data(size):
    data=[]
    for _ in range(size):
        data.append(random.uniform(-10,10))
    return data

def y_data(x1,x2):
    size = len(x1)
    ydata=[]
    for i in range(size):
        if x1[i]+x2[i]>0:
            ydata.append(1)
        else:
            ydata.append(0)
    return ydata

m, n = 1000, 100
x1_train = x_data(m)
x2_train = x_data(m)
y_train = y_data(x1_train, x2_train)
x1_test = x_data(n)
x2_test = x_data(n)
y_test = y_data(x1_test, x2_test)

# %%
# Generate weight, bias
w1,w2,b=random.uniform(-5,5),random.uniform(-5,5),random.uniform(-5,5)

# Define sigmoid function
def sigmoid(value):
    return 1/(1+np.exp(-value))

# Define Loss function
def binary_cross_entropy(predict, actual):
    return -actual*np.log(predict)-(1-actual)*np.log(1-predict)

# %% [markdown]
# ## Forward Propagation
# Given x1, x2
# z = w1·x1 + w2·x2 + b
# a = sigmoid(z)
# J = binary_cross_entropy(a,y)
#
# ## Backword Propagation
# dL/dw = dL/da · da/dz · dz/dw
# dL/da = -y/a -(1-y)/(1-a)
# da/dz = sigmoid(z)·(1-sigmoid(z))
# dz/dw1 = x1, dz/dw2 = x2
# dL/db = dL/da · da/dz · dz/db
# dz/db = 1

# %%
# Define forward,backward propagation, accuracy
def forward(x1,x2,y,w1,w2,b):
    J, dw1, dw2, db= 0, 0, 0, 0
    size = len(x1)
    for i in range(size):
        z = w1*x1[i]+w2*x2[i]+b
        a = sigmoid(z)
        J += binary_cross_entropy(a,y[i])
        dz = a-y[i]
        dw1 += x1[i]*dz
        dw2 += x2[i]*dz
        db += dz
    dw1/=size; dw2/=size; db/= size
    return J,dw1,dw2,db

def backward(w1,w2,b,dw1,dw2,db,alpha):
    w1 -= alpha*dw1
    w2 -= alpha*dw2
    b -= alpha*db
    return w1,w2,b
    
def accuracy(x1,x2,y,w1,w2,b):
    count=0
    for i in range(len(x1)):
        z = w1*x1[i]+w2*x2[i]+b
        a = sigmoid(z)
        if y[i]==round(a):
            count+=1
    return 100*count/len(x1)

# %%
# Elementwise Operation
k = 2000; alpha = 0.01
start_time = time.time()
for epoch in range(1,k+1):
    J, dw1, dw2, db = forward(x1_train,x2_train,y_train,w1,w2,b)
    w1, w2, b = backward(w1,w2,b,dw1,dw2,db,alpha)
    if not epoch%10:
        print('# Epoch:',epoch)
        print('w1, w2, b',(w1,w2,b))
        print('Cost on train:%.4f, Cost on test:%.4f'%(J,forward(x1_test,x2_test,y_test,w1,w2,b)[0]))
        print('Train Accuracy:%.4f, Test Accuracy:%.4f'%(accuracy(x1_train,x2_train,y_train,w1,w2,b),
                                                        accuracy(x1_test,x2_test,y_test,w1,w2,b)))
end_time = time.time()
print('Consumed Time:%.4fseconds'%(end_time-start_time))
# Out:
# <ipython-input-2-a8048b1808b6>:10: RuntimeWarning: divide by zero encountered in log
#   return -actual*np.log(predict)-(1-actual)*np.log(1-predict)
# <ipython-input-2-a8048b1808b6>:10: RuntimeWarning: invalid value encountered in double_scalars
#   return -actual*np.log(predict)-(1-actual)*np.log(1-predict)
# # Epoch: 10
# w1, w2, b (3.6363283074460995, 1.6778642137209197, 1.2648295070146138)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:86.7000, Test Accuracy:89.0000
# # Epoch: 20
# w1, w2, b (3.574148636474638, 1.763684546500303, 1.264309141979171)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:87.5000, Test Accuracy:89.0000
# # Epoch: 30
# w1, w2, b (3.51425420767455, 1.8448986004865675, 1.2638834382181239)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:88.1000, Test Accuracy:89.0000
# # Epoch: 40
# w1, w2, b (3.4568129149212186, 1.9214427778219223, 1.263576599743785)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:89.0000, Test Accuracy:89.0000
# # Epoch: 50
# w1, w2, b (3.4020062464180807, 1.993256864042378, 1.2633944834652506)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:89.6000, Test Accuracy:91.0000
# # Epoch: 60
# w1, w2, b (3.350087001056525, 2.060185730067542, 1.2633032326437768)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:90.2000, Test Accuracy:91.0000
# # Epoch: 70
# w1, w2, b (3.3013051576805736, 2.1220868672291364, 1.2632422707234274)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:91.1000, Test Accuracy:92.0000
# # Epoch: 80
# w1, w2, b (3.2558293156331675, 2.1789486218000835, 1.2631362118917797)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:91.6000, Test Accuracy:92.0000
# # Epoch: 90
# w1, w2, b (3.2137522222565993, 2.2308591766374417, 1.2629138719600423)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:92.4000, Test Accuracy:93.0000
# # Epoch: 100
# w1, w2, b (3.175078904381074, 2.277996215998371, 1.2625282383158147)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:93.2000, Test Accuracy:93.0000
# # Epoch: 110
# w1, w2, b (3.1397017478212144, 2.3206525294221207, 1.2619621881817238)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:93.8000, Test Accuracy:94.0000
# # Epoch: 120
# w1, w2, b (3.1074249006843067, 2.3592045994753974, 1.2612208439280603)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:94.5000, Test Accuracy:94.0000
# # Epoch: 130
# w1, w2, b (3.0780114107192094, 2.3940531669078804, 1.2603209845023702)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:94.8000, Test Accuracy:94.0000
# # Epoch: 140
# w1, w2, b (3.051213402359449, 2.425587626584614, 1.2592837670337067)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:95.4000, Test Accuracy:95.0000
# # Epoch: 150
# w1, w2, b (3.0267858783522144, 2.4541729465894817, 1.2581308263798006)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:95.8000, Test Accuracy:94.0000
# # Epoch: 160
# w1, w2, b (3.004495758750281, 2.480143064121785, 1.256882285369051)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:96.3000, Test Accuracy:94.0000
# # Epoch: 170
# w1, w2, b (2.984130100472023, 2.5037949016613186, 1.255555721942688)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:96.8000, Test Accuracy:94.0000
# # Epoch: 180
# w1, w2, b (2.965501524095655, 2.5253849595167863, 1.2541657705967013)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:97.0000, Test Accuracy:94.0000
# # Epoch: 190
# w1, w2, b (2.94844900693775, 2.545130624394483, 1.2527242353204464)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:97.3000, Test Accuracy:95.0000
# # Epoch: 200
# w1, w2, b (2.9328348022725494, 2.5632154270152565, 1.2512405148691208)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:97.3000, Test Accuracy:95.0000
# # Epoch: 210
# w1, w2, b (2.918539650442897, 2.5797958817843814, 1.2497221152154507)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:97.6000, Test Accuracy:95.0000
# # Epoch: 220
# w1, w2, b (2.9054581433008537, 2.595007877943726, 1.2481751041671147)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:97.7000, Test Accuracy:95.0000
# # Epoch: 230
# w1, w2, b (2.8934951563890796, 2.6089716513718386, 1.246604458484833)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:97.7000, Test Accuracy:96.0000
# # Epoch: 240
# w1, w2, b (2.8825634910482942, 2.6217952237065485, 1.2450143104273383)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:97.8000, Test Accuracy:96.0000
# # Epoch: 250
# w1, w2, b (2.8725824819707726, 2.6335766174448008, 1.243408119764763)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:97.8000, Test Accuracy:96.0000
# # Epoch: 260
# w1, w2, b (2.8634772300355373, 2.6444052530835047, 1.2417887967918682)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.1000, Test Accuracy:97.0000
# # Epoch: 270
# w1, w2, b (2.855178171422869, 2.654362870865137, 1.2401587949721402)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 280
# w1, w2, b (2.8476207898888974, 2.663524209138875, 1.2385201847286482)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.3000, Test Accuracy:98.0000
# # Epoch: 290
# w1, w2, b (2.8407453668249745, 2.6719575713980155, 1.2368747146316894)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.3000, Test Accuracy:98.0000
# # Epoch: 300
# w1, w2, b (2.8344967247970105, 2.6797253442439963, 1.2352238630608492)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.3000, Test Accuracy:98.0000
# # Epoch: 310
# w1, w2, b (2.8288239548045078, 2.6868844882027614, 1.2335688818705413)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.3000, Test Accuracy:98.0000
# # Epoch: 320
# w1, w2, b (2.823680132876281, 2.6934870042712165, 1.2319108330242747)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.3000, Test Accuracy:98.0000
# # Epoch: 330
# w1, w2, b (2.819022035806265, 2.6995803725817913, 1.2302506190540112)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.3000, Test Accuracy:98.0000
# # Epoch: 340
# w1, w2, b (2.8148098647624855, 2.7052079591790967, 1.2285890082199653)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.3000, Test Accuracy:98.0000
# # Epoch: 350
# w1, w2, b (2.8110069827200124, 2.710409388719994, 1.2269266552442055)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.4000, Test Accuracy:98.0000
# # Epoch: 360
# w1, w2, b (2.8075796689087786, 2.7152208829968987, 1.2252641184311346)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 370
# w1, w2, b (2.8044968913669637, 2.7196755667872012, 1.2236018738826262)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 380
# w1, w2, b (2.8017300973342807, 2.723803743497419, 1.2219403273915992)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.0000, Test Accuracy:98.0000
# # Epoch: 390
# w1, w2, b (2.799253020470945, 2.7276331434982675, 1.2202798244767872)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.0000, Test Accuracy:98.0000
# # Epoch: 400
# w1, w2, b (2.7970415035614185, 2.731189148101668, 1.2186206589161248)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.0000, Test Accuracy:98.0000
# # Epoch: 410
# w1, w2, b (2.795073335294428, 2.734494991964466, 1.2169630800512987)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.1000, Test Accuracy:98.0000
# # Epoch: 420
# w1, w2, b (2.793328099782921, 2.7375719464291026, 1.215307299071161)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.1000, Test Accuracy:98.0000
# # Epoch: 430
# w1, w2, b (2.791787037621705, 2.7404394860020878, 1.2136534944340054)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.1000, Test Accuracy:98.0000
# # Epoch: 440
# w1, w2, b (2.7904329174306857, 2.743115439869565, 1.2120018165544069)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.1000, Test Accuracy:98.0000
# # Epoch: 450
# w1, w2, b (2.7892499169737888, 2.745616130076888, 1.2103523918558647)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.1000, Test Accuracy:98.0000
# # Epoch: 460
# w1, w2, b (2.788223513067336, 2.7479564977638073, 1.208705326272953)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.1000, Test Accuracy:98.0000
# # Epoch: 470
# w1, w2, b (2.787340379594116, 2.750150218649259, 1.207060708273838)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.1000, Test Accuracy:98.0000
# # Epoch: 480
# w1, w2, b (2.786588293021908, 2.752209808796289, 1.2054186114642598)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 490
# w1, w2, b (2.7859560448907255, 2.754146721553576, 1.2037790968263768)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 500
# w1, w2, b (2.78543336078496, 2.755971436460149, 1.202142214639483)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 510
# w1, w2, b (2.785010825348071, 2.7576935408095675, 1.2005080061241518)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 520
# w1, w2, b (2.78467981293117, 2.7593218044949612, 1.1988765048465482)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 530
# w1, w2, b (2.784432423495002, 2.7608642486936232, 1.1972477379153474)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 540
# w1, w2, b (2.7842614234089322, 2.7623282088966485, 1.1956217269998275)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 550
# w1, w2, b (2.784160190811939, 2.7637203927434055, 1.1939984891942002)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 560
# w1, w2, b (2.784122665220018, 2.765046933080759, 1.192378037750084)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 570
# w1, w2, b (2.7841433010824383, 2.7663134366318416, 1.1907603826961988)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 580
# w1, w2, b (2.784217025006364, 2.7675250286277784, 1.1891455313618233)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 590
# w1, w2, b (2.784339196385572, 2.768686393727534, 1.1875334888183235)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 600
# w1, w2, b (2.7845055711846785, 2.769801813525376, 1.1859242582510636)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 610
# w1, w2, b (2.7847122686453005, 2.7708752009220348, 1.1843178412722812)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 620
# w1, w2, b (2.784955740695113, 2.7719101316140833, 1.1827142381839844)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 630
# w1, w2, b (2.7852327438546998, 2.7729098729362835, 1.1811134481986045)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 640
# w1, w2, b (2.7855403134505337, 2.7738774102733017, 1.1795154696239931)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 650
# w1, w2, b (2.7858757399552223, 2.774815471240296, 1.1779203000183702)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 660
# w1, w2, b (2.786236547288437, 2.77572654781621, 1.1763279363199701)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 670
# w1, w2, b (2.7866204729235777, 2.7766129165990763, 1.1747383749554194)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 680
# w1, w2, b (2.7870254496562956, 2.777476657339225, 1.173151611930243)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 690
# w1, w2, b (2.787449588901428, 2.77831966989384, 1.1715676429043782)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 700
# w1, w2, b (2.7878911653947656, 2.779143689734796, 1.1699864632551165)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 710
# w1, w2, b (2.788348603185331, 2.7799503021310623, 1.1684080681295177)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 720
# w1, w2, b (2.788820462812524, 2.7807409551171345, 1.166832452488012)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 730
# w1, w2, b (2.7893054295706157, 2.7815169713498284, 1.1652596111406328)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 740
# w1, w2, b (2.7898023027706658, 2.782279558947441, 1.163689538777091)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 750
# w1, w2, b (2.7903099859169935, 2.783029821397483, 1.1621222299917096)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 760
# w1, w2, b (2.7908274777219106, 2.783768766612094, 1.1605576793040693)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 770
# w1, w2, b (2.791353863888528, 2.7844973152036823, 1.1589958811760763)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 780
# w1, w2, b (2.791888309597091, 2.7852163080472643, 1.1574368300260545)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 790
# w1, w2, b (2.79243005263556, 2.7859265131904314, 1.1558805202403548)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 800
# w1, w2, b (2.7929783971199704, 2.786628632166759, 1.1543269461829049)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 810
# w1, w2, b (2.7935327077545944, 2.7873233057637674, 1.1527761022030474)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 820
# w1, w2, b (2.7940924045860496, 2.7880111192922294, 1.1512279826419523)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 830
# w1, w2, b (2.794656958209307, 2.7886926073996667, 1.1496825818378513)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 840
# w1, w2, b (2.7952258853870404, 2.7893682584672304, 1.1481398941302956)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 850
# w1, w2, b (2.7957987450470125, 2.7900385186258387, 1.1465999138636052)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 860
# w1, w2, b (2.796375134625127, 2.790703795424379, 1.1450626353896494)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 870
# w1, w2, b (2.796954686724512, 2.7913644611799864, 1.143528053070078)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 880
# w1, w2, b (2.797537066063524, 2.7920208560378503, 1.1419961612780951)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 890
# w1, w2, b (2.79812196668782, 2.7926732907656264, 1.1404669543998622)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 900
# w1, w2, b (2.79870910942379, 2.7933220493054165, 1.1389404268355954)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 910
# w1, w2, b (2.7992982395525536, 2.7939673911042693, 1.137416573000408)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 920
# w1, w2, b (2.799889124685509, 2.794609553242382, 1.1358953873249518)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 930
# w1, w2, b (2.800481552824034, 2.795248752376522, 1.1343768642558905)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 940
# w1, w2, b (2.8010753305874516, 2.7958851865146626, 1.1328609982562379)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 950
# w1, w2, b (2.8016702815947014, 2.79651903663648, 1.1313477838055863)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 960
# w1, w2, b (2.8022662449864355, 2.7971504681730646, 1.1298372154002476)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 970
# w1, w2, b (2.802863074075391, 2.797779632358064, 1.1283292875533248)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 980
# w1, w2, b (2.8034606351139204, 2.7984066674614088, 1.1268239947947267)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 990
# w1, w2, b (2.8040588061685496, 2.7990316999158127, 1.1253213316711392)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 1000
# w1, w2, b (2.8046574760922747, 2.7996548453453602, 1.123821292745963)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 1010
# w1, w2, b (2.8052565435861343, 2.8002762095046756, 1.1223238725992255)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 1020
# w1, w2, b (2.8058559163423125, 2.8008958891364473, 1.1208290658274713)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 1030
# w1, w2, b (2.806455510261696, 2.8015139727543974, 1.1193368670436414)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.2000, Test Accuracy:98.0000
# # Epoch: 1040
# w1, w2, b (2.807055248739433, 2.8021305413581685, 1.1178472708769382)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.3000, Test Accuracy:98.0000
# # Epoch: 1050
# w1, w2, b (2.8076550620125826, 2.802745669086057, 1.1163602719726875)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.3000, Test Accuracy:98.0000
# # Epoch: 1060
# w1, w2, b (2.8082548865644728, 2.8033594238109796, 1.114875864992193)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.3000, Test Accuracy:98.0000
# # Epoch: 1070
# w1, w2, b (2.8088546645808306, 2.80397186768462, 1.1133940446125934)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.3000, Test Accuracy:98.0000
# # Epoch: 1080
# w1, w2, b (2.8094543434532064, 2.8045830576342516, 1.1119148055267125)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.3000, Test Accuracy:98.0000
# # Epoch: 1090
# w1, w2, b (2.8100538753255635, 2.8051930458163543, 1.1104381424429177)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.3000, Test Accuracy:98.0000
# # Epoch: 1100
# w1, w2, b (2.8106532166802944, 2.805801880030789, 1.1089640500849747)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.3000, Test Accuracy:98.0000
# # Epoch: 1110
# w1, w2, b (2.8112523279602377, 2.8064096040989384, 1.107492523191907)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.3000, Test Accuracy:98.0000
# # Epoch: 1120
# w1, w2, b (2.811851173223564, 2.8070162582089755, 1.1060235565178618)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.3000, Test Accuracy:98.0000
# # Epoch: 1130
# w1, w2, b (2.81244971982867, 2.8076218792311005, 1.1045571448319724)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.3000, Test Accuracy:98.0000
# # Epoch: 1140
# w1, w2, b (2.8130479381464846, 2.8082265010053558, 1.103093282918232)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.3000, Test Accuracy:98.0000
# # Epoch: 1150
# w1, w2, b (2.8136458012977874, 2.8088301546044203, 1.1016319655753666)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.3000, Test Accuracy:98.0000
# # Epoch: 1160
# w1, w2, b (2.8142432849133803, 2.8094328685735435, 1.1001731876167147)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.3000, Test Accuracy:98.0000
# # Epoch: 1170
# w1, w2, b (2.814840366915118, 2.8100346691496174, 1.0987169438701097)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.3000, Test Accuracy:98.0000
# # Epoch: 1180
# w1, w2, b (2.8154370273159754, 2.8106355804611938, 1.0972632291777666)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.3000, Test Accuracy:98.0000
# # Epoch: 1190
# w1, w2, b (2.8160332480375208, 2.8112356247111108, 1.0958120383961722)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.3000, Test Accuracy:98.0000
# # Epoch: 1200
# w1, w2, b (2.8166290127432507, 2.8118348223432355, 1.0943633663959824)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.3000, Test Accuracy:98.0000
# # Epoch: 1210
# w1, w2, b (2.817224306686433, 2.8124331921947108, 1.0929172080619183)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.3000, Test Accuracy:98.0000
# # Epoch: 1220
# w1, w2, b (2.8178191165711794, 2.8130307516349657, 1.091473558292669)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.3000, Test Accuracy:98.0000
# # Epoch: 1230
# w1, w2, b (2.8184134304256054, 2.8136275166926294, 1.0900324120007974)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.3000, Test Accuracy:98.0000
# # Epoch: 1240
# w1, w2, b (2.819007237486021, 2.8142235021714233, 1.0885937641126493)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.3000, Test Accuracy:98.0000
# # Epoch: 1250
# w1, w2, b (2.8196005280912018, 2.814818721755967, 1.0871576095682642)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.3000, Test Accuracy:98.0000
# # Epoch: 1260
# w1, w2, b (2.820193293585851, 2.8154131881083924, 1.0857239433212922)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.3000, Test Accuracy:98.0000
# # Epoch: 1270
# w1, w2, b (2.820785526232465, 2.816006912956555, 1.0842927603389092)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.3000, Test Accuracy:98.0000
# # Epoch: 1280
# w1, w2, b (2.8213772191308624, 2.8165999071745804, 1.0828640556017393)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.3000, Test Accuracy:98.0000
# # Epoch: 1290
# w1, w2, b (2.821968366144716, 2.817192180856408, 1.0814378241037768)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.3000, Test Accuracy:98.0000
# # Epoch: 1300
# w1, w2, b (2.822558961834475, 2.817783743382942, 1.0800140608523106)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.3000, Test Accuracy:98.0000
# # Epoch: 1310
# w1, w2, b (2.8231490013961262, 2.8183746034833654, 1.0785927608678536)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.3000, Test Accuracy:98.0000
# # Epoch: 1320
# w1, w2, b (2.8237384806052788, 2.81896476929113, 1.0771739191840706)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.3000, Test Accuracy:98.0000
# # Epoch: 1330
# w1, w2, b (2.8243273957661192, 2.8195542483950793, 1.0757575308477092)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.3000, Test Accuracy:98.0000
# # Epoch: 1340
# w1, w2, b (2.824915743664801, 2.8201430478861242, 1.0743435909185355)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.3000, Test Accuracy:98.0000
# # Epoch: 1350
# w1, w2, b (2.825503521526897, 2.8207311743998718, 1.072932094469266)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.3000, Test Accuracy:98.0000
# # Epoch: 1360
# w1, w2, b (2.8260907269785513, 2.8213186341555434, 1.0715230365855053)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.3000, Test Accuracy:98.0000
# # Epoch: 1370
# w1, w2, b (2.8266773580110107, 2.82190543299152, 1.0701164123656857)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.3000, Test Accuracy:98.0000
# # Epoch: 1380
# w1, w2, b (2.827263412948242, 2.8224915763977947, 1.068712216921005)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.3000, Test Accuracy:98.0000
# # Epoch: 1390
# w1, w2, b (2.8278488904173744, 2.823077069545606, 1.0673104453753672)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.3000, Test Accuracy:98.0000
# # Epoch: 1400
# w1, w2, b (2.8284337893217053, 2.8236619173145034, 1.0659110928653253)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.3000, Test Accuracy:98.0000
# # Epoch: 1410
# w1, w2, b (2.8290181088160646, 2.8242461243170593, 1.0645141545400238)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.3000, Test Accuracy:98.0000
# # Epoch: 1420
# w1, w2, b (2.829601848284316, 2.8248296949214358, 1.0631196255611446)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.3000, Test Accuracy:98.0000
# # Epoch: 1430
# w1, w2, b (2.8301850073188204, 2.8254126332719953, 1.0617275011028497)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.3000, Test Accuracy:98.0000
# # Epoch: 1440
# w1, w2, b (2.8307675857016905, 2.8259949433081193, 1.0603377763517308)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.3000, Test Accuracy:98.0000
# # Epoch: 1450
# w1, w2, b (2.831349583387673, 2.8265766287813996, 1.0589504465067536)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.3000, Test Accuracy:98.0000
# # Epoch: 1460
# w1, w2, b (2.831931000488525, 2.8271576932713307, 1.057565506779208)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.4000, Test Accuracy:98.0000
# # Epoch: 1470
# w1, w2, b (2.832511837258749, 2.8277381401996498, 1.0561829523926562)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.4000, Test Accuracy:98.0000
# # Epoch: 1480
# w1, w2, b (2.83309209408257, 2.8283179728434242, 1.0548027785828815)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.4000, Test Accuracy:98.0000
# # Epoch: 1490
# w1, w2, b (2.8336717714620523, 2.8288971943470154, 1.0534249805978406)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.4000, Test Accuracy:98.0000
# # Epoch: 1500
# w1, w2, b (2.8342508700062488, 2.829475807732994, 1.0520495536976142)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.4000, Test Accuracy:98.0000
# # Epoch: 1510
# w1, w2, b (2.8348293904212936, 2.8300538159121187, 1.050676493154357)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.4000, Test Accuracy:98.0000
# # Epoch: 1520
# w1, w2, b (2.8354073335013648, 2.8306312216924474, 1.0493057942522526)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.4000, Test Accuracy:98.0000
# # Epoch: 1530
# w1, w2, b (2.8359847001204295, 2.8312080277876595, 1.0479374522874652)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.4000, Test Accuracy:98.0000
# # Epoch: 1540
# w1, w2, b (2.8365614912247112, 2.831784236824655, 1.0465714625680929)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.4000, Test Accuracy:98.0000
# # Epoch: 1550
# w1, w2, b (2.837137707825817, 2.832359851350501, 1.0452078204141215)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.4000, Test Accuracy:98.0000
# # Epoch: 1560
# w1, w2, b (2.837713350994462, 2.8329348738387785, 1.0438465211573817)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.4000, Test Accuracy:98.0000
# # Epoch: 1570
# w1, w2, b (2.838288421854742, 2.8335093066953725, 1.0424875601415007)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.4000, Test Accuracy:98.0000
# # Epoch: 1580
# w1, w2, b (2.83886292157891, 2.8340831522637693, 1.0411309327218592)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.4000, Test Accuracy:98.0000
# # Epoch: 1590
# w1, w2, b (2.8394368513826027, 2.8346564128298968, 1.0397766342655475)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.4000, Test Accuracy:98.0000
# # Epoch: 1600
# w1, w2, b (2.840010212520491, 2.835229090626538, 1.0384246601513212)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.4000, Test Accuracy:98.0000
# # Epoch: 1610
# w1, w2, b (2.840583006282311, 2.8358011878373737, 1.0370750057695588)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.4000, Test Accuracy:98.0000
# # Epoch: 1620
# w1, w2, b (2.8411552339892356, 2.8363727066006748, 1.035727666522218)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.4000, Test Accuracy:98.0000
# # Epoch: 1630
# w1, w2, b (2.8417268969905725, 2.836943649012672, 1.0343826378227934)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.4000, Test Accuracy:98.0000
# # Epoch: 1640
# w1, w2, b (2.8422979966607445, 2.8375140171306374, 1.0330399150962746)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.4000, Test Accuracy:98.0000
# # Epoch: 1650
# w1, w2, b (2.842868534396544, 2.8380838129757078, 1.0316994937791046)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.4000, Test Accuracy:98.0000
# # Epoch: 1660
# w1, w2, b (2.8434385116146204, 2.838653038535454, 1.0303613693191374)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.4000, Test Accuracy:98.0000
# # Epoch: 1670
# w1, w2, b (2.8440079297491883, 2.839221695766237, 1.029025537175598)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.5000, Test Accuracy:98.0000
# # Epoch: 1680
# w1, w2, b (2.844576790249945, 2.8397897865953627, 1.0276919928190402)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.5000, Test Accuracy:98.0000
# # Epoch: 1690
# w1, w2, b (2.8451450945801664, 2.840357312923046, 1.026360731731307)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.5000, Test Accuracy:98.0000
# # Epoch: 1700
# w1, w2, b (2.8457128442149684, 2.8409242766242144, 1.0250317494054904)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.5000, Test Accuracy:98.0000
# # Epoch: 1710
# w1, w2, b (2.8462800406397277, 2.8414906795501524, 1.023705041345891)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.5000, Test Accuracy:98.0000
# # Epoch: 1720
# w1, w2, b (2.8468466853486403, 2.8420565235300095, 1.022380603067978)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.5000, Test Accuracy:98.0000
# # Epoch: 1730
# w1, w2, b (2.8474127798434057, 2.8426218103721728, 1.0210584300983507)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.5000, Test Accuracy:98.0000
# # Epoch: 1740
# w1, w2, b (2.84797832563203, 2.8431865418655335, 1.019738517974698)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.5000, Test Accuracy:98.0000
# # Epoch: 1750
# w1, w2, b (2.8485433242277374, 2.8437507197806373, 1.0184208622457607)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.5000, Test Accuracy:98.0000
# # Epoch: 1760
# w1, w2, b (2.849107777147971, 2.8443143458707394, 1.017105458471292)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.5000, Test Accuracy:98.0000
# # Epoch: 1770
# w1, w2, b (2.8496716859134947, 2.8448774218727766, 1.0157923022220192)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.5000, Test Accuracy:98.0000
# # Epoch: 1780
# w1, w2, b (2.8502350520475668, 2.845439949508246, 1.0144813890796056)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.5000, Test Accuracy:98.0000
# # Epoch: 1790
# w1, w2, b (2.8507978770751894, 2.8460019304840203, 1.0131727146366127)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.5000, Test Accuracy:98.0000
# # Epoch: 1800
# w1, w2, b (2.8513601625224285, 2.846563366493088, 1.0118662744964615)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.5000, Test Accuracy:98.0000
# # Epoch: 1810
# w1, w2, b (2.8519219099157924, 2.847124259215239, 1.0105620642733966)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.5000, Test Accuracy:98.0000
# # Epoch: 1820
# w1, w2, b (2.85248312078167, 2.847684610317683, 1.0092600795924465)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.5000, Test Accuracy:98.0000
# # Epoch: 1830
# w1, w2, b (2.853043796645814, 2.848244421455626, 1.0079603160893884)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.5000, Test Accuracy:98.0000
# # Epoch: 1840
# w1, w2, b (2.853603939032882, 2.848803694272797, 1.006662769410712)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.5000, Test Accuracy:98.0000
# # Epoch: 1850
# w1, w2, b (2.8541635494660067, 2.849362430401924, 1.0053674352135795)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.5000, Test Accuracy:98.0000
# # Epoch: 1860
# w1, w2, b (2.854722629466419, 2.8499206314651833, 1.0040743091657913)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.5000, Test Accuracy:98.0000
# # Epoch: 1870
# w1, w2, b (2.8552811805530958, 2.8504782990746005, 1.0027833869457512)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.5000, Test Accuracy:98.0000
# # Epoch: 1880
# w1, w2, b (2.855839204242447, 2.85103543483243, 1.0014946642424263)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.5000, Test Accuracy:98.0000
# # Epoch: 1890
# w1, w2, b (2.856396702048028, 2.851592040331494, 1.000208136755315)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.5000, Test Accuracy:98.0000
# # Epoch: 1900
# w1, w2, b (2.856953675480286, 2.8521481171554983, 0.9989238001944083)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.5000, Test Accuracy:98.0000
# # Epoch: 1910
# w1, w2, b (2.8575101260463205, 2.8527036668793277, 0.9976416502801563)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.5000, Test Accuracy:98.0000
# # Epoch: 1920
# w1, w2, b (2.858066055249678, 2.8532586910693114, 0.9963616827434316)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.5000, Test Accuracy:98.0000
# # Epoch: 1930
# w1, w2, b (2.8586214645901586, 2.853813191283468, 0.9950838933254951)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.5000, Test Accuracy:98.0000
# # Epoch: 1940
# w1, w2, b (2.859176355563646, 2.854367169071737, 0.99380827777796)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.5000, Test Accuracy:98.0000
# # Epoch: 1950
# w1, w2, b (2.859730729661952, 2.8549206259761872, 0.9925348318627575)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.5000, Test Accuracy:98.0000
# # Epoch: 1960
# w1, w2, b (2.86028458837268, 2.855473563531212, 0.9912635513521019)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.5000, Test Accuracy:98.0000
# # Epoch: 1970
# w1, w2, b (2.8608379331790994, 2.856025983263708, 0.9899944320284567)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.5000, Test Accuracy:98.0000
# # Epoch: 1980
# w1, w2, b (2.8613907655600364, 2.8565778866932447, 0.9887274696845)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.5000, Test Accuracy:98.0000
# # Epoch: 1990
# w1, w2, b (2.8619430869897706, 2.8571292753322144, 0.9874626601230896)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.5000, Test Accuracy:98.0000
# # Epoch: 2000
# w1, w2, b (2.8624948989379533, 2.8576801506859777, 0.9861999991572307)
# Cost on train:nan, Cost on test:nan
# Train Accuracy:98.5000, Test Accuracy:98.0000
# Consumed Time:19.1485seconds

# %%
# Generate new weight, bias for comparison
w1,w2,b=random.uniform(-5,5),random.uniform(-5,5),random.uniform(-5,5)

def cost(x,y,w,b):
    z = np.dot(w,x)+b
    a = sigmoid(z)
    J = binary_cross_entropy(a,y)
    return J.sum()

# %%
# Vectorized Operation
x_train = np.array([x1_train,x2_train])
x_test = np.array([x1_test,x2_test])
ytrain = np.array(y_train)
ytest = np.array(y_test)
w = np.array([w1,w2])
start_time = time.time()
for epoch in range(1,k+1):
    z = np.dot(w,x_train)+b
    a = sigmoid(z)
    J = binary_cross_entropy(a,ytrain)
    dz = a-ytrain
    dw1 = np.dot(dz,x_train[0]).sum()/m
    dw2 = np.dot(dz,x_train[1]).sum()/m
    w -= np.array([alpha*dw1,alpha*dw2])
    b -= alpha*db.sum()/m
    if not epoch%10:
        print('# Epoch:',epoch)
        print('w1, w2, b',(w1,w2,b))
        print('Cost on train:%.4f, Cost on test:%.4f'%(J.sum(),cost(x_test,ytest,w,b)))
        print('Train Accuracy:%.4f, Test Accuracy:%.4f'%(accuracy(x1_train,x2_train,y_train,w[0],w[1],b),
                                                        accuracy(x1_test,x2_test,y_test,w[0],w[1],b)))
end_time = time.time()
print('Consumed Time:%.4fseconds'%(end_time-start_time))
# Out:
# # Epoch: 10
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3311280228047817)
# Cost on train:inf, Cost on test:inf
# Train Accuracy:3.5000, Test Accuracy:6.0000
# # Epoch: 20
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331129284500072)
# Cost on train:inf, Cost on test:inf
# Train Accuracy:4.0000, Test Accuracy:7.0000
# # Epoch: 30
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3311305461953626)
# Cost on train:13174.9037, Cost on test:1307.7480
# Train Accuracy:5.0000, Test Accuracy:7.0000
# # Epoch: 40
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331131807890653)
# Cost on train:10758.9379, Cost on test:1065.5917
# Train Accuracy:6.5000, Test Accuracy:9.0000
# # Epoch: 50
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3311330695859436)
# Cost on train:8370.1504, Cost on test:826.0610
# Train Accuracy:8.9000, Test Accuracy:11.0000
# # Epoch: 60
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331134331281234)
# Cost on train:6036.9631, Cost on test:592.2836
# Train Accuracy:13.2000, Test Accuracy:14.0000
# # Epoch: 70
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3311355929765245)
# Cost on train:3845.8307, Cost on test:374.1542
# Train Accuracy:21.1000, Test Accuracy:23.0000
# # Epoch: 80
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331136854671815)
# Cost on train:2120.3958, Cost on test:206.8508
# Train Accuracy:43.4000, Test Accuracy:44.0000
# # Epoch: 90
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3311381163671054)
# Cost on train:1215.0854, Cost on test:117.3574
# Train Accuracy:47.4000, Test Accuracy:46.0000
# # Epoch: 100
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331139378062396)
# Cost on train:767.2244, Cost on test:73.5000
# Train Accuracy:56.8000, Test Accuracy:58.0000
# # Epoch: 110
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3311406397576864)
# Cost on train:585.0191, Cost on test:56.4031
# Train Accuracy:68.5000, Test Accuracy:71.0000
# <ipython-input-2-a8048b1808b6>:10: RuntimeWarning: divide by zero encountered in log
#   return -actual*np.log(predict)-(1-actual)*np.log(1-predict)
# # Epoch: 120
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331141901452977)
# Cost on train:497.1205, Cost on test:48.3272
# Train Accuracy:73.6000, Test Accuracy:76.0000
# # Epoch: 130
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3311431631482673)
# Cost on train:444.5098, Cost on test:43.5873
# Train Accuracy:76.2000, Test Accuracy:78.0000
# # Epoch: 140
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3311444248435578)
# Cost on train:408.6411, Cost on test:40.4065
# Train Accuracy:77.9000, Test Accuracy:80.0000
# # Epoch: 150
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3311456865388482)
# Cost on train:382.1247, Cost on test:38.0832
# Train Accuracy:79.4000, Test Accuracy:81.0000
# # Epoch: 160
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3311469482341387)
# Cost on train:361.4318, Cost on test:36.2861
# Train Accuracy:80.5000, Test Accuracy:81.0000
# # Epoch: 170
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331148209929429)
# Cost on train:344.6521, Cost on test:34.8382
# Train Accuracy:81.4000, Test Accuracy:82.0000
# # Epoch: 180
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3311494716247196)
# Cost on train:330.6527, Cost on test:33.6355
# Train Accuracy:81.9000, Test Accuracy:82.0000
# # Epoch: 190
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.33115073332001)
# Cost on train:318.7149, Cost on test:32.6130
# Train Accuracy:82.4000, Test Accuracy:82.0000
# # Epoch: 200
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3311519950153006)
# Cost on train:308.3577, Cost on test:31.7273
# Train Accuracy:83.2000, Test Accuracy:82.0000
# # Epoch: 210
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331153256710591)
# Cost on train:299.2455, Cost on test:30.9486
# Train Accuracy:83.4000, Test Accuracy:82.0000
# # Epoch: 220
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3311545184058815)
# Cost on train:291.1360, Cost on test:30.2555
# Train Accuracy:84.1000, Test Accuracy:82.0000
# # Epoch: 230
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331155780101172)
# Cost on train:283.8489, Cost on test:29.6323
# Train Accuracy:84.4000, Test Accuracy:83.0000
# # Epoch: 240
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3311570417964624)
# Cost on train:277.2471, Cost on test:29.0671
# Train Accuracy:84.8000, Test Accuracy:83.0000
# # Epoch: 250
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331158303491753)
# Cost on train:271.2241, Cost on test:28.5506
# Train Accuracy:85.0000, Test Accuracy:83.0000
# # Epoch: 260
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3311595651870434)
# Cost on train:265.6954, Cost on test:28.0756
# Train Accuracy:85.0000, Test Accuracy:83.0000
# # Epoch: 270
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331160826882334)
# Cost on train:260.5935, Cost on test:27.6363
# Train Accuracy:85.0000, Test Accuracy:86.0000
# # Epoch: 280
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3311620885776243)
# Cost on train:255.8632, Cost on test:27.2281
# Train Accuracy:85.7000, Test Accuracy:87.0000
# # Epoch: 290
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3311633502729148)
# Cost on train:251.4589, Cost on test:26.8471
# Train Accuracy:85.9000, Test Accuracy:87.0000
# # Epoch: 300
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3311646119682052)
# Cost on train:247.3429, Cost on test:26.4902
# Train Accuracy:86.2000, Test Accuracy:87.0000
# # Epoch: 310
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3311658736634957)
# Cost on train:243.4832, Cost on test:26.1546
# Train Accuracy:86.2000, Test Accuracy:87.0000
# # Epoch: 320
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331167135358786)
# Cost on train:239.8530, Cost on test:25.8382
# Train Accuracy:86.6000, Test Accuracy:87.0000
# # Epoch: 330
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3311683970540766)
# Cost on train:236.4290, Cost on test:25.5389
# Train Accuracy:86.9000, Test Accuracy:87.0000
# # Epoch: 340
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331169658749367)
# Cost on train:233.1915, Cost on test:25.2552
# Train Accuracy:87.1000, Test Accuracy:87.0000
# # Epoch: 350
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3311709204446576)
# Cost on train:230.1231, Cost on test:24.9856
# Train Accuracy:87.2000, Test Accuracy:87.0000
# # Epoch: 360
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331172182139948)
# Cost on train:227.2087, Cost on test:24.7288
# Train Accuracy:87.8000, Test Accuracy:87.0000
# # Epoch: 370
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3311734438352385)
# Cost on train:224.4354, Cost on test:24.4839
# Train Accuracy:87.8000, Test Accuracy:87.0000
# # Epoch: 380
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331174705530529)
# Cost on train:221.7913, Cost on test:24.2498
# Train Accuracy:87.8000, Test Accuracy:87.0000
# # Epoch: 390
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3311759672258194)
# Cost on train:219.2662, Cost on test:24.0256
# Train Accuracy:87.8000, Test Accuracy:87.0000
# # Epoch: 400
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.33117722892111)
# Cost on train:216.8509, Cost on test:23.8107
# Train Accuracy:87.9000, Test Accuracy:87.0000
# # Epoch: 410
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3311784906164004)
# Cost on train:214.5374, Cost on test:23.6043
# Train Accuracy:88.3000, Test Accuracy:87.0000
# # Epoch: 420
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331179752311691)
# Cost on train:212.3182, Cost on test:23.4059
# Train Accuracy:88.3000, Test Accuracy:87.0000
# # Epoch: 430
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3311810140069813)
# Cost on train:210.1868, Cost on test:23.2148
# Train Accuracy:88.4000, Test Accuracy:87.0000
# # Epoch: 440
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3311822757022718)
# Cost on train:208.1372, Cost on test:23.0307
# Train Accuracy:88.6000, Test Accuracy:87.0000
# # Epoch: 450
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3311835373975622)
# Cost on train:206.1641, Cost on test:22.8531
# Train Accuracy:88.6000, Test Accuracy:87.0000
# # Epoch: 460
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3311847990928527)
# Cost on train:204.2625, Cost on test:22.6815
# Train Accuracy:88.6000, Test Accuracy:87.0000
# # Epoch: 470
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331186060788143)
# Cost on train:202.4280, Cost on test:22.5156
# Train Accuracy:88.6000, Test Accuracy:87.0000
# # Epoch: 480
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3311873224834336)
# Cost on train:200.6566, Cost on test:22.3551
# Train Accuracy:88.8000, Test Accuracy:87.0000
# # Epoch: 490
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331188584178724)
# Cost on train:198.9445, Cost on test:22.1997
# Train Accuracy:88.8000, Test Accuracy:87.0000
# # Epoch: 500
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3311898458740146)
# Cost on train:197.2883, Cost on test:22.0490
# Train Accuracy:89.0000, Test Accuracy:87.0000
# # Epoch: 510
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331191107569305)
# Cost on train:195.6849, Cost on test:21.9029
# Train Accuracy:89.0000, Test Accuracy:87.0000
# # Epoch: 520
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3311923692645955)
# Cost on train:194.1313, Cost on test:21.7610
# Train Accuracy:89.3000, Test Accuracy:87.0000
# # Epoch: 530
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331193630959886)
# Cost on train:192.6250, Cost on test:21.6232
# Train Accuracy:89.3000, Test Accuracy:88.0000
# # Epoch: 540
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3311948926551764)
# Cost on train:191.1634, Cost on test:21.4892
# Train Accuracy:89.5000, Test Accuracy:88.0000
# # Epoch: 550
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331196154350467)
# Cost on train:189.7443, Cost on test:21.3589
# Train Accuracy:89.8000, Test Accuracy:88.0000
# # Epoch: 560
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3311974160457574)
# Cost on train:188.3655, Cost on test:21.2321
# Train Accuracy:89.8000, Test Accuracy:88.0000
# # Epoch: 570
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331198677741048)
# Cost on train:187.0251, Cost on test:21.1086
# Train Accuracy:89.9000, Test Accuracy:88.0000
# # Epoch: 580
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3311999394363383)
# Cost on train:185.7213, Cost on test:20.9882
# Train Accuracy:90.0000, Test Accuracy:88.0000
# # Epoch: 590
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3312012011316288)
# Cost on train:184.4522, Cost on test:20.8709
# Train Accuracy:90.0000, Test Accuracy:88.0000
# # Epoch: 600
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3312024628269192)
# Cost on train:183.2164, Cost on test:20.7565
# Train Accuracy:90.0000, Test Accuracy:88.0000
# # Epoch: 610
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3312037245222097)
# Cost on train:182.0123, Cost on test:20.6449
# Train Accuracy:90.3000, Test Accuracy:88.0000
# # Epoch: 620
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3312049862175)
# Cost on train:180.8385, Cost on test:20.5358
# Train Accuracy:90.4000, Test Accuracy:88.0000
# # Epoch: 630
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3312062479127906)
# Cost on train:179.6938, Cost on test:20.4294
# Train Accuracy:90.5000, Test Accuracy:88.0000
# # Epoch: 640
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331207509608081)
# Cost on train:178.5768, Cost on test:20.3253
# Train Accuracy:90.5000, Test Accuracy:88.0000
# # Epoch: 650
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3312087713033716)
# Cost on train:177.4864, Cost on test:20.2236
# Train Accuracy:90.6000, Test Accuracy:88.0000
# # Epoch: 660
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331210032998662)
# Cost on train:176.4216, Cost on test:20.1241
# Train Accuracy:90.6000, Test Accuracy:88.0000
# # Epoch: 670
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3312112946939525)
# Cost on train:175.3812, Cost on test:20.0268
# Train Accuracy:90.7000, Test Accuracy:88.0000
# # Epoch: 680
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331212556389243)
# Cost on train:174.3644, Cost on test:19.9316
# Train Accuracy:90.9000, Test Accuracy:88.0000
# # Epoch: 690
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3312138180845334)
# Cost on train:173.3702, Cost on test:19.8383
# Train Accuracy:91.1000, Test Accuracy:88.0000
# # Epoch: 700
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331215079779824)
# Cost on train:172.3977, Cost on test:19.7470
# Train Accuracy:91.1000, Test Accuracy:88.0000
# # Epoch: 710
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3312163414751144)
# Cost on train:171.4462, Cost on test:19.6575
# Train Accuracy:91.1000, Test Accuracy:88.0000
# # Epoch: 720
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331217603170405)
# Cost on train:170.5148, Cost on test:19.5698
# Train Accuracy:91.1000, Test Accuracy:88.0000
# # Epoch: 730
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3312188648656953)
# Cost on train:169.6028, Cost on test:19.4838
# Train Accuracy:91.1000, Test Accuracy:88.0000
# # Epoch: 740
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3312201265609858)
# Cost on train:168.7095, Cost on test:19.3995
# Train Accuracy:91.2000, Test Accuracy:88.0000
# # Epoch: 750
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3312213882562762)
# Cost on train:167.8343, Cost on test:19.3168
# Train Accuracy:91.2000, Test Accuracy:88.0000
# # Epoch: 760
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3312226499515667)
# Cost on train:166.9766, Cost on test:19.2356
# Train Accuracy:91.3000, Test Accuracy:88.0000
# # Epoch: 770
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331223911646857)
# Cost on train:166.1356, Cost on test:19.1560
# Train Accuracy:91.3000, Test Accuracy:88.0000
# # Epoch: 780
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3312251733421476)
# Cost on train:165.3110, Cost on test:19.0778
# Train Accuracy:91.3000, Test Accuracy:88.0000
# # Epoch: 790
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331226435037438)
# Cost on train:164.5020, Cost on test:19.0010
# Train Accuracy:91.3000, Test Accuracy:88.0000
# # Epoch: 800
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3312276967327286)
# Cost on train:163.7083, Cost on test:18.9255
# Train Accuracy:91.3000, Test Accuracy:88.0000
# # Epoch: 810
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331228958428019)
# Cost on train:162.9292, Cost on test:18.8514
# Train Accuracy:91.3000, Test Accuracy:88.0000
# # Epoch: 820
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3312302201233095)
# Cost on train:162.1644, Cost on test:18.7785
# Train Accuracy:91.4000, Test Accuracy:89.0000
# # Epoch: 830
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3312314818186)
# Cost on train:161.4135, Cost on test:18.7069
# Train Accuracy:91.4000, Test Accuracy:89.0000
# # Epoch: 840
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3312327435138904)
# Cost on train:160.6758, Cost on test:18.6365
# Train Accuracy:91.5000, Test Accuracy:89.0000
# # Epoch: 850
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331234005209181)
# Cost on train:159.9512, Cost on test:18.5673
# Train Accuracy:91.6000, Test Accuracy:89.0000
# # Epoch: 860
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3312352669044714)
# Cost on train:159.2391, Cost on test:18.4991
# Train Accuracy:91.7000, Test Accuracy:90.0000
# # Epoch: 870
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331236528599762)
# Cost on train:158.5392, Cost on test:18.4321
# Train Accuracy:91.7000, Test Accuracy:90.0000
# # Epoch: 880
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3312377902950523)
# Cost on train:157.8511, Cost on test:18.3662
# Train Accuracy:91.7000, Test Accuracy:90.0000
# # Epoch: 890
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3312390519903428)
# Cost on train:157.1746, Cost on test:18.3012
# Train Accuracy:91.7000, Test Accuracy:90.0000
# # Epoch: 900
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3312403136856332)
# Cost on train:156.5092, Cost on test:18.2373
# Train Accuracy:91.7000, Test Accuracy:90.0000
# # Epoch: 910
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3312415753809237)
# Cost on train:155.8546, Cost on test:18.1744
# Train Accuracy:91.7000, Test Accuracy:90.0000
# # Epoch: 920
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331242837076214)
# Cost on train:155.2106, Cost on test:18.1124
# Train Accuracy:91.7000, Test Accuracy:90.0000
# # Epoch: 930
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3312440987715046)
# Cost on train:154.5768, Cost on test:18.0514
# Train Accuracy:91.8000, Test Accuracy:90.0000
# # Epoch: 940
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331245360466795)
# Cost on train:153.9530, Cost on test:17.9912
# Train Accuracy:91.8000, Test Accuracy:90.0000
# # Epoch: 950
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3312466221620856)
# Cost on train:153.3389, Cost on test:17.9320
# Train Accuracy:91.8000, Test Accuracy:90.0000
# # Epoch: 960
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331247883857376)
# Cost on train:152.7342, Cost on test:17.8736
# Train Accuracy:91.9000, Test Accuracy:90.0000
# # Epoch: 970
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3312491455526665)
# Cost on train:152.1387, Cost on test:17.8160
# Train Accuracy:91.9000, Test Accuracy:90.0000
# # Epoch: 980
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331250407247957)
# Cost on train:151.5522, Cost on test:17.7592
# Train Accuracy:91.9000, Test Accuracy:90.0000
# # Epoch: 990
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3312516689432474)
# Cost on train:150.9744, Cost on test:17.7033
# Train Accuracy:91.9000, Test Accuracy:90.0000
# # Epoch: 1000
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331252930638538)
# Cost on train:150.4051, Cost on test:17.6481
# Train Accuracy:91.9000, Test Accuracy:90.0000
# # Epoch: 1010
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3312541923338284)
# Cost on train:149.8440, Cost on test:17.5937
# Train Accuracy:91.9000, Test Accuracy:90.0000
# # Epoch: 1020
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331255454029119)
# Cost on train:149.2911, Cost on test:17.5400
# Train Accuracy:91.9000, Test Accuracy:90.0000
# # Epoch: 1030
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3312567157244093)
# Cost on train:148.7460, Cost on test:17.4870
# Train Accuracy:92.0000, Test Accuracy:90.0000
# # Epoch: 1040
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3312579774196998)
# Cost on train:148.2086, Cost on test:17.4347
# Train Accuracy:92.0000, Test Accuracy:90.0000
# # Epoch: 1050
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3312592391149902)
# Cost on train:147.6787, Cost on test:17.3831
# Train Accuracy:92.0000, Test Accuracy:90.0000
# # Epoch: 1060
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3312605008102807)
# Cost on train:147.1561, Cost on test:17.3322
# Train Accuracy:92.0000, Test Accuracy:90.0000
# # Epoch: 1070
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331261762505571)
# Cost on train:146.6407, Cost on test:17.2820
# Train Accuracy:92.1000, Test Accuracy:90.0000
# # Epoch: 1080
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3312630242008616)
# Cost on train:146.1322, Cost on test:17.2323
# Train Accuracy:92.2000, Test Accuracy:90.0000
# # Epoch: 1090
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331264285896152)
# Cost on train:145.6306, Cost on test:17.1833
# Train Accuracy:92.2000, Test Accuracy:90.0000
# # Epoch: 1100
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3312655475914426)
# Cost on train:145.1356, Cost on test:17.1349
# Train Accuracy:92.2000, Test Accuracy:90.0000
# # Epoch: 1110
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331266809286733)
# Cost on train:144.6471, Cost on test:17.0872
# Train Accuracy:92.2000, Test Accuracy:90.0000
# # Epoch: 1120
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3312680709820235)
# Cost on train:144.1650, Cost on test:17.0400
# Train Accuracy:92.2000, Test Accuracy:90.0000
# # Epoch: 1130
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331269332677314)
# Cost on train:143.6891, Cost on test:16.9933
# Train Accuracy:92.4000, Test Accuracy:90.0000
# # Epoch: 1140
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3312705943726044)
# Cost on train:143.2193, Cost on test:16.9472
# Train Accuracy:92.5000, Test Accuracy:90.0000
# # Epoch: 1150
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331271856067895)
# Cost on train:142.7554, Cost on test:16.9017
# Train Accuracy:92.5000, Test Accuracy:90.0000
# # Epoch: 1160
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3312731177631854)
# Cost on train:142.2973, Cost on test:16.8567
# Train Accuracy:92.5000, Test Accuracy:90.0000
# # Epoch: 1170
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331274379458476)
# Cost on train:141.8450, Cost on test:16.8123
# Train Accuracy:92.5000, Test Accuracy:90.0000
# # Epoch: 1180
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3312756411537663)
# Cost on train:141.3982, Cost on test:16.7683
# Train Accuracy:92.5000, Test Accuracy:90.0000
# # Epoch: 1190
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3312769028490568)
# Cost on train:140.9568, Cost on test:16.7249
# Train Accuracy:92.5000, Test Accuracy:90.0000
# # Epoch: 1200
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331278164544347)
# Cost on train:140.5208, Cost on test:16.6819
# Train Accuracy:92.5000, Test Accuracy:90.0000
# # Epoch: 1210
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3312794262396377)
# Cost on train:140.0901, Cost on test:16.6395
# Train Accuracy:92.5000, Test Accuracy:90.0000
# # Epoch: 1220
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331280687934928)
# Cost on train:139.6644, Cost on test:16.5975
# Train Accuracy:92.5000, Test Accuracy:90.0000
# # Epoch: 1230
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3312819496302186)
# Cost on train:139.2438, Cost on test:16.5559
# Train Accuracy:92.5000, Test Accuracy:90.0000
# # Epoch: 1240
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331283211325509)
# Cost on train:138.8281, Cost on test:16.5149
# Train Accuracy:92.5000, Test Accuracy:90.0000
# # Epoch: 1250
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3312844730207996)
# Cost on train:138.4172, Cost on test:16.4742
# Train Accuracy:92.6000, Test Accuracy:90.0000
# # Epoch: 1260
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.33128573471609)
# Cost on train:138.0110, Cost on test:16.4340
# Train Accuracy:92.6000, Test Accuracy:90.0000
# # Epoch: 1270
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3312869964113805)
# Cost on train:137.6095, Cost on test:16.3943
# Train Accuracy:92.6000, Test Accuracy:90.0000
# # Epoch: 1280
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331288258106671)
# Cost on train:137.2125, Cost on test:16.3549
# Train Accuracy:92.6000, Test Accuracy:90.0000
# # Epoch: 1290
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3312895198019614)
# Cost on train:136.8200, Cost on test:16.3160
# Train Accuracy:92.6000, Test Accuracy:90.0000
# # Epoch: 1300
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331290781497252)
# Cost on train:136.4318, Cost on test:16.2775
# Train Accuracy:92.6000, Test Accuracy:90.0000
# # Epoch: 1310
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3312920431925424)
# Cost on train:136.0479, Cost on test:16.2394
# Train Accuracy:92.6000, Test Accuracy:90.0000
# # Epoch: 1320
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331293304887833)
# Cost on train:135.6682, Cost on test:16.2017
# Train Accuracy:92.6000, Test Accuracy:90.0000
# # Epoch: 1330
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3312945665831233)
# Cost on train:135.2926, Cost on test:16.1643
# Train Accuracy:92.6000, Test Accuracy:90.0000
# # Epoch: 1340
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3312958282784138)
# Cost on train:134.9211, Cost on test:16.1273
# Train Accuracy:92.6000, Test Accuracy:90.0000
# # Epoch: 1350
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331297089973704)
# Cost on train:134.5535, Cost on test:16.0907
# Train Accuracy:92.6000, Test Accuracy:90.0000
# # Epoch: 1360
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3312983516689947)
# Cost on train:134.1899, Cost on test:16.0545
# Train Accuracy:92.6000, Test Accuracy:90.0000
# # Epoch: 1370
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331299613364285)
# Cost on train:133.8301, Cost on test:16.0186
# Train Accuracy:92.6000, Test Accuracy:90.0000
# # Epoch: 1380
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3313008750595756)
# Cost on train:133.4740, Cost on test:15.9831
# Train Accuracy:92.6000, Test Accuracy:90.0000
# # Epoch: 1390
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331302136754866)
# Cost on train:133.1216, Cost on test:15.9479
# Train Accuracy:92.6000, Test Accuracy:90.0000
# # Epoch: 1400
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3313033984501565)
# Cost on train:132.7729, Cost on test:15.9131
# Train Accuracy:92.6000, Test Accuracy:90.0000
# # Epoch: 1410
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331304660145447)
# Cost on train:132.4277, Cost on test:15.8786
# Train Accuracy:92.7000, Test Accuracy:90.0000
# # Epoch: 1420
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3313059218407375)
# Cost on train:132.0860, Cost on test:15.8444
# Train Accuracy:92.7000, Test Accuracy:90.0000
# # Epoch: 1430
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331307183536028)
# Cost on train:131.7478, Cost on test:15.8106
# Train Accuracy:92.7000, Test Accuracy:90.0000
# # Epoch: 1440
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3313084452313184)
# Cost on train:131.4129, Cost on test:15.7770
# Train Accuracy:92.7000, Test Accuracy:90.0000
# # Epoch: 1450
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331309706926609)
# Cost on train:131.0814, Cost on test:15.7438
# Train Accuracy:92.7000, Test Accuracy:90.0000
# # Epoch: 1460
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3313109686218993)
# Cost on train:130.7531, Cost on test:15.7109
# Train Accuracy:92.8000, Test Accuracy:90.0000
# # Epoch: 1470
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.33131223031719)
# Cost on train:130.4281, Cost on test:15.6783
# Train Accuracy:92.8000, Test Accuracy:90.0000
# # Epoch: 1480
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3313134920124803)
# Cost on train:130.1062, Cost on test:15.6459
# Train Accuracy:92.9000, Test Accuracy:90.0000
# # Epoch: 1490
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3313147537077707)
# Cost on train:129.7874, Cost on test:15.6139
# Train Accuracy:92.9000, Test Accuracy:90.0000
# # Epoch: 1500
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331316015403061)
# Cost on train:129.4717, Cost on test:15.5822
# Train Accuracy:93.1000, Test Accuracy:90.0000
# # Epoch: 1510
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3313172770983517)
# Cost on train:129.1589, Cost on test:15.5507
# Train Accuracy:93.2000, Test Accuracy:90.0000
# # Epoch: 1520
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331318538793642)
# Cost on train:128.8492, Cost on test:15.5195
# Train Accuracy:93.2000, Test Accuracy:90.0000
# # Epoch: 1530
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3313198004889326)
# Cost on train:128.5423, Cost on test:15.4886
# Train Accuracy:93.2000, Test Accuracy:90.0000
# # Epoch: 1540
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331321062184223)
# Cost on train:128.2383, Cost on test:15.4580
# Train Accuracy:93.2000, Test Accuracy:90.0000
# # Epoch: 1550
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3313223238795135)
# Cost on train:127.9371, Cost on test:15.4276
# Train Accuracy:93.3000, Test Accuracy:90.0000
# # Epoch: 1560
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331323585574804)
# Cost on train:127.6387, Cost on test:15.3975
# Train Accuracy:93.3000, Test Accuracy:90.0000
# # Epoch: 1570
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3313248472700945)
# Cost on train:127.3431, Cost on test:15.3676
# Train Accuracy:93.3000, Test Accuracy:90.0000
# # Epoch: 1580
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331326108965385)
# Cost on train:127.0501, Cost on test:15.3380
# Train Accuracy:93.3000, Test Accuracy:90.0000
# # Epoch: 1590
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3313273706606754)
# Cost on train:126.7597, Cost on test:15.3087
# Train Accuracy:93.3000, Test Accuracy:90.0000
# # Epoch: 1600
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331328632355966)
# Cost on train:126.4720, Cost on test:15.2796
# Train Accuracy:93.3000, Test Accuracy:90.0000
# # Epoch: 1610
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3313298940512563)
# Cost on train:126.1868, Cost on test:15.2507
# Train Accuracy:93.4000, Test Accuracy:90.0000
# # Epoch: 1620
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331331155746547)
# Cost on train:125.9041, Cost on test:15.2221
# Train Accuracy:93.4000, Test Accuracy:91.0000
# # Epoch: 1630
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3313324174418373)
# Cost on train:125.6240, Cost on test:15.1937
# Train Accuracy:93.4000, Test Accuracy:91.0000
# # Epoch: 1640
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3313336791371277)
# Cost on train:125.3462, Cost on test:15.1655
# Train Accuracy:93.4000, Test Accuracy:91.0000
# # Epoch: 1650
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331334940832418)
# Cost on train:125.0709, Cost on test:15.1376
# Train Accuracy:93.4000, Test Accuracy:91.0000
# # Epoch: 1660
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3313362025277087)
# Cost on train:124.7980, Cost on test:15.1099
# Train Accuracy:93.5000, Test Accuracy:91.0000
# # Epoch: 1670
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331337464222999)
# Cost on train:124.5274, Cost on test:15.0824
# Train Accuracy:93.5000, Test Accuracy:91.0000
# # Epoch: 1680
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3313387259182896)
# Cost on train:124.2591, Cost on test:15.0552
# Train Accuracy:93.6000, Test Accuracy:91.0000
# # Epoch: 1690
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.33133998761358)
# Cost on train:123.9931, Cost on test:15.0281
# Train Accuracy:93.7000, Test Accuracy:91.0000
# # Epoch: 1700
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3313412493088705)
# Cost on train:123.7294, Cost on test:15.0013
# Train Accuracy:93.7000, Test Accuracy:91.0000
# # Epoch: 1710
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331342511004161)
# Cost on train:123.4678, Cost on test:14.9747
# Train Accuracy:93.7000, Test Accuracy:91.0000
# # Epoch: 1720
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3313437726994515)
# Cost on train:123.2084, Cost on test:14.9483
# Train Accuracy:93.7000, Test Accuracy:91.0000
# # Epoch: 1730
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331345034394742)
# Cost on train:122.9512, Cost on test:14.9220
# Train Accuracy:93.8000, Test Accuracy:91.0000
# # Epoch: 1740
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3313462960900324)
# Cost on train:122.6961, Cost on test:14.8960
# Train Accuracy:93.8000, Test Accuracy:91.0000
# # Epoch: 1750
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331347557785323)
# Cost on train:122.4431, Cost on test:14.8702
# Train Accuracy:93.8000, Test Accuracy:91.0000
# # Epoch: 1760
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3313488194806133)
# Cost on train:122.1921, Cost on test:14.8446
# Train Accuracy:93.8000, Test Accuracy:91.0000
# # Epoch: 1770
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331350081175904)
# Cost on train:121.9431, Cost on test:14.8192
# Train Accuracy:93.9000, Test Accuracy:91.0000
# # Epoch: 1780
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3313513428711943)
# Cost on train:121.6962, Cost on test:14.7940
# Train Accuracy:93.9000, Test Accuracy:91.0000
# # Epoch: 1790
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3313526045664847)
# Cost on train:121.4512, Cost on test:14.7689
# Train Accuracy:93.9000, Test Accuracy:91.0000
# # Epoch: 1800
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331353866261775)
# Cost on train:121.2082, Cost on test:14.7441
# Train Accuracy:93.9000, Test Accuracy:91.0000
# # Epoch: 1810
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3313551279570657)
# Cost on train:120.9671, Cost on test:14.7194
# Train Accuracy:93.9000, Test Accuracy:91.0000
# # Epoch: 1820
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331356389652356)
# Cost on train:120.7279, Cost on test:14.6949
# Train Accuracy:93.9000, Test Accuracy:91.0000
# # Epoch: 1830
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3313576513476466)
# Cost on train:120.4906, Cost on test:14.6706
# Train Accuracy:93.9000, Test Accuracy:91.0000
# # Epoch: 1840
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331358913042937)
# Cost on train:120.2551, Cost on test:14.6464
# Train Accuracy:93.9000, Test Accuracy:91.0000
# # Epoch: 1850
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3313601747382275)
# Cost on train:120.0214, Cost on test:14.6225
# Train Accuracy:93.9000, Test Accuracy:91.0000
# # Epoch: 1860
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331361436433518)
# Cost on train:119.7896, Cost on test:14.5987
# Train Accuracy:94.0000, Test Accuracy:91.0000
# # Epoch: 1870
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3313626981288085)
# Cost on train:119.5595, Cost on test:14.5751
# Train Accuracy:94.0000, Test Accuracy:91.0000
# # Epoch: 1880
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331363959824099)
# Cost on train:119.3311, Cost on test:14.5516
# Train Accuracy:94.0000, Test Accuracy:91.0000
# # Epoch: 1890
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3313652215193894)
# Cost on train:119.1045, Cost on test:14.5283
# Train Accuracy:94.1000, Test Accuracy:91.0000
# # Epoch: 1900
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.33136648321468)
# Cost on train:118.8796, Cost on test:14.5052
# Train Accuracy:94.1000, Test Accuracy:91.0000
# # Epoch: 1910
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3313677449099703)
# Cost on train:118.6564, Cost on test:14.4822
# Train Accuracy:94.1000, Test Accuracy:91.0000
# # Epoch: 1920
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331369006605261)
# Cost on train:118.4348, Cost on test:14.4594
# Train Accuracy:94.1000, Test Accuracy:91.0000
# # Epoch: 1930
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3313702683005513)
# Cost on train:118.2149, Cost on test:14.4368
# Train Accuracy:94.1000, Test Accuracy:91.0000
# # Epoch: 1940
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3313715299958417)
# Cost on train:117.9966, Cost on test:14.4143
# Train Accuracy:94.1000, Test Accuracy:91.0000
# # Epoch: 1950
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331372791691132)
# Cost on train:117.7798, Cost on test:14.3919
# Train Accuracy:94.1000, Test Accuracy:91.0000
# # Epoch: 1960
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3313740533864227)
# Cost on train:117.5647, Cost on test:14.3698
# Train Accuracy:94.1000, Test Accuracy:91.0000
# # Epoch: 1970
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331375315081713)
# Cost on train:117.3511, Cost on test:14.3477
# Train Accuracy:94.1000, Test Accuracy:91.0000
# # Epoch: 1980
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3313765767770036)
# Cost on train:117.1391, Cost on test:14.3258
# Train Accuracy:94.2000, Test Accuracy:91.0000
# # Epoch: 1990
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.331377838472294)
# Cost on train:116.9286, Cost on test:14.3041
# Train Accuracy:94.2000, Test Accuracy:91.0000
# # Epoch: 2000
# w1, w2, b (-2.8240494796992763, -2.8933120483559236, -2.3313791001675845)
# Cost on train:116.7196, Cost on test:14.2825
# Train Accuracy:94.2000, Test Accuracy:91.0000
# Consumed Time:1.4297seconds

# %% [markdown]
# # Practice #2
# * Input: 2-dim vector, x = {x1,x2}
# * Output: label of the input, y = 0 or 1

# %%
# Initiate
import random
import numpy as np
import time

# Generate Dataset
def x_data(size):
    data=[]
    for _ in range(size):
        data.append(random.uniform(-10,10))
    return data

def y_data(x1,x2):
    size = len(x1)
    ydata=[]
    for i in range(size):
        if x1[i]+x2[i]>0:
            ydata.append(1)
        else:
            ydata.append(0)
    return ydata

m, n = 10000, 500
x1_train = x_data(m)
x2_train = x_data(m)
y_train = y_data(x1_train, x2_train)
x1_test = x_data(n)
x2_test = x_data(n)
y_test = y_data(x1_test, x2_test)


# Functions
def sigmoid(value):
    return 1/(1+np.exp(-value))

def cost(predict, actual):
    if actual:
        if predict<1e-8:
            predict = 1e-8
        return -np.log(predict)
    else:
        if predict>1-1e-8:
            predict = 1-1e-8
        return -np.log(1-predict)

def accuracy(predict, actual):
    count = 0; total = len(predict)
    for i in range(total):
        if predict[i] == actual[i]:
            count+=1
    return 100*count/total

# %% [markdown]
# * Task1: Binary Classification using 2-layered net (cross-entropy loss)
# [x00,x01] -> y

# %%
# Generate new weight, bias for comparison
w1,w2,b=random.uniform(-5,5),random.uniform(-5,5),random.uniform(-5,5)

# def forward(x0,):
# What is Thr. = 0.5??

# Vectorized Operation
x_train = np.array([x1_train,x2_train])
x_test = np.array([x1_test,x2_test])
ytrain = np.array(y_train)
ytest = np.array(y_test)
w = np.array([w1,w2])
start_time = time.time()
for epoch in range(1,k+1):
    z = np.dot(w,x_train)+b
    a = sigmoid(z)
    J = binary_cross_entropy(a,ytrain)
    dz = a-ytrain
    dw1 = np.dot(dz,x_train[0]).sum()/m
    dw2 = np.dot(dz,x_train[1]).sum()/m
    w -= np.array([alpha*dw1,alpha*dw2])
    b -= alpha*db.sum()/m
    if not epoch%10:
        print('# Epoch:',epoch)
        print('w1, w2, b',(w1,w2,b))
        print('Cost on train:%.4f, Cost on test:%.4f'%(J.sum(),cost(x_test,ytest,w,b)))
        print('Train Accuracy:%.4f, Test Accuracy:%.4f'%(accuracy(x1_train,x2_train,y_train,w[0],w[1],b),
                                                        accuracy(x1_test,x2_test,y_test,w[0],w[1],b)))
end_time = time.time()
print('Consumed Time:%.4fseconds'%(end_time-start_time))

# %% [markdown]
# * Task2: Binary Classification using 2-layered net (cross-entropy loss)
# [x00,x01] -> [x10] -> [x20] -> y

# %%
# Generate new weight, bias for comparison
w00,w01,b0=random.uniform(-5,5),random.uniform(-5,5),random.uniform(-5,5)
w10,w20=random.uniform(-5,5),random.uniform(-5,5)
b1,b2,k=random.uniform(-5,5),random.uniform(-5,5),5000

x0 = np.array([x1_train,x2_train])
x0_test = np.array([x1_test,x2_test])
ytrain = np.array(y_train)
ytest = np.array(y_test)
w0 = np.array([w00,w01])
start_time = time.time()
for epoch in range(1,k+1):
    x1 = np.dot(w,x0) + b0
    z1 = sigmoid(x1)
    x2 = np.dot(w10,z1) + b1
    z2 = sigmoid(x2)
    x3 = np.dot(w20,z2) + b2
    d
    if not epoch%50:
        print('# Epoch:',epoch
end_time = time.time()
print('Consumed Time:%.4fseconds'%(end_time-start_time))

# %%
x0
# Out:
# array([[-6.56093384, -0.94240961,  4.56541315, ..., -8.93647557,
#         -3.99494616, -2.67481609],
#        [ 2.96644978, -6.91001003, -4.14779281, ...,  8.21097785,
#          9.56392353,  4.53759728]])

# %%
w
# Out:
# array([ 1.89150889, -2.29465754])

# %%
np.dot(w,x0)+b0
# Out:
# array([-17.11252082,  16.1780606 ,  20.25781373, ..., -33.64027498,
#        -27.39787519, -13.36714003])

# %% [markdown]
# * Task3: Binary Classification using wide 2-layered net (cross-entropy loss)
# [x00,x01] -> [x10,x11,x12] -> [x20] -> y
